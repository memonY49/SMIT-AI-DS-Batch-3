# %%
class vehical:
    color = ''
    no_doors = 0
    no_seats = 0
    no_weels = 0
    hp = 0
    def acc(self):
        print("change in speed")
    def breaks(self):
        print("reduce speed")
    def start(self):
        print('engin ignites')

# %%
corola = vehical()

# %%
corola.acc()
# Out:
# change in speed

# %%
corola.color = 'white'

# %%
corola.color
# Out:
# 'white'

# %%
mehran = vehical()

# %%
mehran.color = 'blue'

# %%
print(corola.color,mehran.color)
# Out:
# white blue

# %%
class calculator:
    def add(self,a,b):
        print(a+b)
    def sub(self,a,b):
        print(a-b)
    def mul(self,a,b):
        print(a*b)
    def devision(self,a,b):
        print(a/b)

# %%
cal = calculator()

# %%
calculator.add(cal,2,4)
# Out:
# 6

# %% [markdown]
# # Scope of a variable
# 1. Global
# 2. functional
# 3. class
# 4. static
